# %%
import torch
from torch import nn
import torchaudio
from torchaudio import transforms

from AudioVAE import *

# %%
model = AudioVAE()

# %%
model.load_state_dict(torch.load('../audio_vae_0.pth', map_location='cpu'))
# Out:
# <All keys matched successfully>

# %%
sample = torch.randn((1, 100))
ms = model.decoder(sample)

# %%
ms.size()
# Out:
# torch.Size([1, 2, 128, 400])

# %%
from librosa import feature

waveform = feature.inverse.mel_to_audio(ms.detach().numpy()[0], sr=8000)

# %%
from IPython.display import Audio

# %%
Audio(data=waveform, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
waveform = invert_mel_spectrogram(ms[0][0])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10936/4159459025.py in <module>
# ----> 1 waveform = invert_mel_spectrogram(ms[0][0])
#
# ~\AppData\Local\Temp/ipykernel_10936/2368972027.py in invert_mel_spectrogram(mel_spec, sample_rate)
#       5
#       6     # Invert mel spectrogram to waveform
# ----> 7     waveform = griffin_lim(mel_spec)
#       8
#       9     # Resample to the desired sample rate
#
# ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# ...
